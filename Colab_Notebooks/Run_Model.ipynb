# %% [markdown]
# 1) Mounting Google Drive for accessing Training Dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2) Coverting Jupyter Notebooks to text files. Change extensions of the created files to .py (python script) for command line execution.

# %%
# %cd /content/drive/MyDrive/Terrain_Classification_Project/Colab_Notebooks
# !pwd
# !jupyter nbconvert --to script 'Train_Model.ipynb'
# Out:
# /content/drive/MyDrive/Colab_Notebooks
# /content/drive/MyDrive/Colab_Notebooks
# [NbConvertApp] Converting notebook Train_Model.ipynb to script
# [NbConvertApp] Writing 6152 bytes to Train_Model.txt

# %% [markdown]
# 3) Unzipping the dataset in Google Drive to the current instance of colab notebook for faster processing.

# %%
# %cd /content/
# !pwd
# !mkdir Train_Dataset
# !unzip "/content/drive/MyDrive/Terrain_Classification_Project/Terrain_Classification_Data/Train_Dataset/Dirt_Road.zip" -d "/content/Train_Dataset"
# !unzip "/content/drive/MyDrive/Terrain_Classification_Project/Terrain_Classification_Data/Train_Dataset/Mud.zip" -d "/content/Train_Dataset"
# !unzip "/content/drive/MyDrive/Terrain_Classification_Project/Terrain_Classification_Data/Road.zip" -d "/content/Train_Dataset"
# !unzip "/content/drive/MyDrive/Terrain_Classification_Project/Terrain_Classification_Data/Rock.zip" -d "/content/Train_Dataset"
# !unzip "/content/drive/MyDrive/Terrain_Classification_Project/Terrain_Classification_Data/Snow.zip" -d "/content/Train_Dataset"
# Out:
# /content
# /content

# %% [markdown]
# 4) Command to start training the Model.

# %% [markdown]
# (The RAM on Google Colab is suddenly overwhelmed during Training for some reason, needs debugging. Code should work on local computer)

# %%
# !python "/content/drive/MyDrive/Terrain_Classification_Project/Colab_Notebooks/Train_Model.py" --dataset "/content/Train_Dataset" --model "/content/drive/MyDrive/Terrain_Classification_Project/Colab_Notebooks/Model/terrain.model" --label-bin "/content/drive/MyDrive/Terrain_Classification_Project/Colab_Notebooks/Label_Bin/lb.pickle" --epochs "10"
# Out:
# 2021-07-31 13:14:07.129448: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ArgumentParser(prog='Train_Model.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)
# 2021-07-31 13:14:10.381579: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-31 13:14:10.461945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-31 13:14:10.462640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# (Optional) Command to check allocated GPU resources in Colab

# %%
#!nvidia-smi
# Out:
# Sat Jul 31 13:17:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
